# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import sys
sys.path.append("/mnt/d/00_SARDARCHITECTLABS/projects/fscoreai-ml/")

from fscoreai.utils import utils
from fscoreai.sample_data import sample_data

# %% [markdown]
# # Regression Datasets

# %%
# Simulated Linear Data

X, y = sample_data.simulate_linear_data()
print(X.shape, y.shape)

fig, axs = plt.subplots(1, 1)
ax1 = axs.scatter(X, y)
plt.show()
# Out:
# (100, 1) (100,)

# %%
# House prices
# X.cols = (sqft_living, year_built)
# y.cols = (price)

X, y = sample_data.kc_house_data()
print(X.shape, y.shape)
print(X)
print(y)

fig, axs = plt.subplots(2, 1)
ax1 = axs[0].scatter(X[:, 0], y)
ax2 = axs[1].scatter(X[:, 1], y)
plt.show()
# Out:
# (21613, 2) (21613,)
# [[1180 1955]
#  [2570 1951]
#  [ 770 1933]
#  ...
#  [1020 2009]
#  [1600 2004]
#  [1020 2008]]
# [221900. 538000. 180000. ... 402101. 400000. 325000.]

# %%
# Salary Data
# X.cols = (Years of Experience)
# Y.cols = (Salary)
X, y = sample_data.salary_data()
print(X.shape, y.shape)

fig, axs = plt.subplots(1, 1)
ax1 = axs.scatter(X, y)
plt.show()
# Out:
# (30,) (30,)

# %%
# Diabetes Data
# X.cols = ("age", "sex", "bmi", "bp", "s1", "s2", "s3", "s4", "s5", "s6")
# Y.cols = (diabetes index)
X, y = sample_data.diabetes_data()
X = X.to_numpy()
y = y.to_numpy().reshape(-1)
print(X.shape, y.shape)

fig, axs = plt.subplots(5, 2)
fig.set_figheight(15)
fig.set_figwidth(15)
n = 0
for i in range(5):
    for j in range(2):
        axs[i, j].scatter(X[:, n], y)
        n = n + 1

plt.show()
# Out:
# (442, 10) (442,)

# %% [markdown]
# # Classification Datasets

# %%
# Simulated Classification Data

X, y = sample_data.simulate_regression_data()
print(X.shape, y.shape)

fig, axs = plt.subplots(1, 1)
ax1 = axs.scatter(X, y)
plt.show()
# Out:
# (30, 1) (30,)

# %%
# Iris Dataset
# X.cols = (sepal_length,sepal_width,petal_length,petal_width)
#y.cols = (species)

X, y = sample_data.iris_data()
print(X.shape, y.shape)

fig, axs = plt.subplots(2, 2)
fig.set_figheight(15)
fig.set_figwidth(15)
n = 0
for i in range(2):
    for j in range(2):
        axs[i, j].scatter(X[:, n], y)
        n = n + 1
# Out:
# (150, 4) (150,)
